# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import urllib.request

# %%
cap = cv2.VideoCapture('input.avi')
frames = []
while True:
    ret, frame = cap.read()
    if not ret: break
    frames.append(frame)
cap.release()
print(f'Read {len(frames)} frames. Reversing...')
for f in reversed(frames):
    pass # would display or write here
print('Reversed!')
